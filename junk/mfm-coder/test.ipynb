# %%
import torch

# %%
a = torch.tensor([1, 0, 0])
b = torch.tensor([0, 1, 0])
# c = torch.tensor([1, 1, 1])

# %%
torch.cross(a, b, dim=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 torch.cross(a, b, dim=0)
#
# RuntimeError: linalg.cross: inputs dimension 0 must have length 3. Got 2 and 2
